# %%
f = open("hotel_train.txt", 'r', encoding="utf-8")

while True:
    line = f.readline()
    if not line: break
    print(' '.join(line.split()[:-1]))
f.close()
# Out:
# text
# 주변 소음
# 방의 건조대가 파손되어 있었던 거
# 그 외에는 가격 대비 상당히 만족도가 높아서 다시 숙박할 의사가 충분했는데 아쉽습니다
# 특히 청결하고 아늑한 실내가 좋았습니다
# 위치 객실 크기 청소 상태 등 등 퍼펙트했어요
# 그래도 이건 같은 층 사용하시는 분들이 매너만 지키시면 문제 될 부분 없을 것 같아요
# 주변 먹거리가 다양하지 않아 찾아다니기는 힘들었습니다
# 실내 수영장이 너무 추워서
# 여의도 일 있을 때 가는 가성비 숙소
# 아무래도 침대가 가장 좋았으며 주변에 번화가가 있어서 저녁 먹을 거리가 많았습니다 고층으로 잡아주셔서 넓은 침대와 전망을 보면서 하루 숙박을 할 수 있었습니다
# 조식 메뉴가 많으면 좋겟어요
# 우산은 5000원 디포짓 내면 프론트에서 빌릴 수 있다
# 위치 굿 탑층 루프탑 카페 좋아요
# 아쉬운 점은 딱히 없었던 거 같아요
# 룸의 조명이 너무 허술해서 편안한 느낌은 없었고 침대도 너무 딱딱해서 조금은 불편했어요
# 뷔페 식당이 맛이 없어요
# 방에 간 이후 고층과 엘리베이터와 가까운 방으로 변경 요청하니 13층으로 배정 받았습니다 만 일 고층을 원하신다면 프론트에 다시 한번 어 필하시기 바랍니다
# 조식의 가성비가 좋지 않음
# 조식이 좀 많이 아쉬웠어요
# 호텔의 위치 때문에 새벽에 좀 시 끄러웠다는 것
# 이 가격에 이 정도 퀄리티면 모텔 가는 것보다 훨씬 좋아요
# 모든 면에서 좋았습니다
# 욕실 면봉에서 머리카락 나왔어요
# 아침부터 기분 잡치고 시작했습니다
# 잠자리도 편하고 쉬기 딱 좋았습니다
# 좀 불편했음
# 깨끗하고 신도림에서 가까워 요
# 층 고가 높아서 트여 있는 느낌이 좋았어용
# 엘레베이터 냄새가 심함
# 샤워시설 가 좋았습니다
# 대신 룸이 쪼끔 좁아요
# 좀 더 넓은 방을 이용할 걸 하는 아쉬움
# 가성비가 좋다는 말이 딱입니다
# 조식 먹을 때 직원분의 친절과 서비스가 너무 좋았어요
# ...

# %%
sents = [
    "룸의 조명이 너무 허술해서 편안한 느낌은 없었고 침대도 너무 딱딱해서 조금은 불편했어요",
    "특히 청결하고 아늑한 실내가 좋았습니다",
    "가성비가 좋다는 말이 딱입니다",
    "조식 먹을 때 직원분의 친절과 서비스가 너무 좋았어요",
    "외부 경치가 정말 최악이었다",
    "조식도 좋고 침대도 편안하고 욕실도 좋았습니다",
    "깔끔하고 포근한 침구에서 잘 쉬었습니다",
    "난방이 좀 잘 안 된 거 같아요",
    "대로변 바로 앞이라 그런지 도로 소음은 있었습니다",
    "뒷길이라 대중교통 이용하는데 좀 불편했어요",
    "건물이 노후화되어 주차시설 및 호텔 침대 등의 사용성이 다소 아쉬웠습니다",
    "서울의 다른 호텔 대비 큰 객실과 저렴한 가격",
    "욕실도 청결하고 침구가 편안했어요",
    "방안에 조리시설이 있어서 간단하게 조식 먹을 수 있음",
    "그리고 위치는 더할 나위 없이 만족입니다",
    "숙소가 많이 건조했습니다",
    "깨끗하고 보안시설이 넘 좋았음",
    "전체적으로 깔끔하고 아늑한 가성비 호텔입니다",
    "조식도 기대 이상이었습니다",
    "방이 생각보다 넓고 화면이 커서 좋습니다",
    "직원들 안내가 친절했고 근처에 대형마트 음식점 편의점이 있어서 편했구요",
    "직원분이 너무 친절하게 대해주셨고 필요했던 물품을 프론트에 부탁했더니 바로 해결해 주셔서 서비스 면에서는 아주 좋습니다",
    "특히 화장실이 너무 좁아서 문을 닫으면 이용할 때 너무 불편해요",
    "홍대역 바로 맞은 편이라 위치가 아주 좋았어요",
    "역까지 멀어서 무조건 택시 타야 해요",
    "기본에 충실하다는 느낌",
    "수영장 이용 시 바닥에 물 때가 너무 많이 끼어 있어 아쉬웠고 수건처럼 아이들 구명조끼가 보이는 곳에 정리되어 있으면 사용사는 사람도 사용한 사람도 정리하기 편리할 것 같았음",
    "저녁에 주는 소바는 솔직히 그저 그랬습니다",
    "진짜 굿 남산뷰"
]

# %%
with open('input_candidate_1.txt', 'w') as f:
    for line in sents:
        f.write(line)
